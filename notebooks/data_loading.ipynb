# %% [markdown]
# # Data loading and structuring
#
# The code in this notebook loads all the recordings from the Jarinos folder and saves all vocalizations separately in the vocalizations folder, organized per seal.
#
# It also creates a dataframe and csv file with all metadata per vocalization.
#
# (Code by Marianne, July 2022)

# %%
import parselmouth
import tgt
import glob
import pandas as pd
import numpy as np
import os

# %%
raw_data_folder = '../data/Jarinos/'
processed_data_folder = '../data/vocalizations/'
months = [6,7]
include_p_vocalizations = True

# %%
info_sheet = pd.read_excel(raw_data_folder + 'Seal_recs_summer17.xlsx', index_col=0)
month_folders = glob.glob(raw_data_folder + '/[01]*')

# %%
# remove empty columns
info_sheet = info_sheet.loc[:, ~info_sheet.columns.str.contains('^Unnamed')]
# add month column
info_sheet['Month'] = info_sheet.apply(lambda row: row.Date.month, axis=1)

# %%
info_sheet
# Out:
#     Folder           Filename       Date  Time   Human   Animal Partners  \
# 3       29          ZOOM0002a 2017-05-29     7    Koen     Info      NaN
# 3       29          ZOOM0003a 2017-05-29     7    Koen  r17-192      NaN
# 3       29          ZOOM0004a 2017-05-29     7    Koen  r17-192      NaN
# 3       29          ZOOM0006a 2017-05-29     7    Koen  r17-192      NaN
# 3       29          ZOOM0007a 2017-05-29     7    Koen  r17-192      NaN
# ..     ...                ...        ...   ...     ...      ...      ...
# 63      28           ZOOM0007 2017-07-28     7  Andrea  r17-294  r17-295
# 63      28           ZOOM0008 2017-07-28     7  Andrea  r17-302  r17-303
# 63      28           ZOOM0024 2017-07-28    11   Marga  r17-288  r17-289
# 63      28           ZOOM0025 2017-07-28    11   Marga  r17-297  r17-299
# 63      28  recording deleted 2017-07-28    19  Andrea  r17-276  r17-277
#
#    Context GoodExcerpt D_0_min  ... D_6_min D_9_min LastKnownLocation Species  \
# 3      NaN         NaN     NaN  ...     NaN     NaN                Q1      PV
# 3      NaN         NaN     NaN  ...     NaN     NaN                Q1      PV
# 3      NaN  Very clear     NaN  ...     NaN     NaN                Q1      PV
# 3      NaN         NaN     NaN  ...     NaN     NaN                Q1      PV
# 3      NaN         NaN     NaN  ...     NaN     NaN                Q1      PV
# ..     ...         ...     ...  ...     ...     ...               ...     ...
# 63     NaN         NaN       3  ...       4       4                J2      PV
# 63     NaN         NaN       1  ...       2       2                J3      PV
# 63     NaN         NaN       3  ...       ?       ?                J8      PV
# 63     NaN         NaN       4  ...       4       4                J1      PV
# 63     NaN         NaN       1  ...       1       1                J7      PV
#
#                                              Comments Annotator  \
# 3                                     Ella ID r17-192         K
# 3                                                 NaN         K
# 3                                                 NaN         K
# 3                                                 NaN         K
# 3                                                 NaN         K
# ..                                                ...       ...
# 63                                                NaN         K
# 63                              Only one voc from 303         K
# 63       Ra wasn't looking good, and did not vocalize         K
# 63  Only 299 vocalized; one on the plateau; the ot...         K
# 63                                                NaN         K
#
#              Annotation Comments Praat (NNCO = Names Not Called Out)  \
# 3                     -                                          NaN
# 3                    97                                          NaN
# 3                     5                                          NaN
# 3                    69                                          NaN
# 3                    37                                          NaN
# ..                  ...                                          ...
# 63  2018-11-25 00:00:00                                          NaN
# 63  2017-01-03 00:00:00                                          NaN
# 63                13-53                                          NaN
# 63                 1-95                                Gain too high
# 63                    -                                          NaN
#
#    Multichannel Month
# 3           NaN     5
# 3           NaN     5
# 3           NaN     5
# 3           NaN     5
# 3           NaN     5
# ..          ...   ...
# 63          NaN     7
# 63          NaN     7
# 63          NaN     7
# 63          NaN     7
# 63          NaN     7
#
# [966 rows x 21 columns]

# %%
# select recordings from the given months that have annotations
rec_selection = info_sheet[(info_sheet['Annotator'].notna()) & (info_sheet['Month'].isin(months))]

# %%
def get_month_folder(month_int, month_folders):
    month_list = [f for f in month_folders if str(month_int) in f]
    assert len(month_list) == 1, f"Missing or multiple folders for this month: {month_int}"
    return month_list[0]

# %%
def get_day_folder(day_int, month_folder, ignore_missing_folders=False):
    day_folders = glob.glob(month_folder + '/*')
    day_str = f"{day_int:02d}"
    day_list = [f for f in day_folders if f[-2:] == day_str]
    if not ignore_missing_folders:
        assert len(day_list) != 0, f"Missing folder for this day: {month_folder}/{day_str}"
    else:
        if len(day_list) == 0:
            return None
    assert len(day_list) < 2, f"Multiple folders for this day: {month_folder}/{day_str}"
    return day_list[0]

# %%
def get_rec_folder(rec_str, day_folder, ignore_missing_folders=False):
    rec_folders = glob.glob(day_folder + '/*')
    rec_list = [f for f in rec_folders if f[-(len(rec_str)):] == rec_str]
    if not ignore_missing_folders:
        assert len(rec_list) != 0, f"Missing folder for this recording: {day_folder}/{rec_str}"
    else:
        if len(rec_list) == 0:
            return None
    assert len(rec_list) < 2, f"Multiple folders for this recording: {day_folder}/{rec_str}"
    return rec_list[0]

# %%
def get_rec_wav(rec_folder):
    wav_files = glob.glob(rec_folder + '/*.WAV') + glob.glob(rec_folder + '/*.wav')
    if len(wav_files) > 1:
        # if there is a transcoded wav file, use that one
        transcoded_wavs = [w for w in wav_files if '_transcoded' in w]
        wav_files = transcoded_wavs
    assert len(wav_files) == 1, f"Missing or multiple WAV files for this recording: {rec_folder}"
    return wav_files[0]

# %%
def get_rec_textgrid(rec_folder):
    textgrid_files = glob.glob(rec_folder + '/*.TextGrid')
    if len(textgrid_files) > 1:
        # if there are multiple textgrid files, use the one named koen
        koen_tgs = [t for t in textgrid_files if '_koen' in t]
        textgrid_files = koen_tgs
    assert len(textgrid_files) == 1, f"Missing or multiple TextGrid files for this recording: {rec_folder}"
    return textgrid_files[0]

# %%
def check_folder(folder_path):
    """
    Create folder if it does not exist, return path.
    """
    if not os.path.isdir(folder_path):
        os.mkdir(folder_path)
    return folder_path

# %%
# %%time
# looping over all data and structuring information
# this cell takes a while (maybe a few mins) and produces a *lot* of warnings about clipping

processed_data_folder = check_folder(processed_data_folder)
    
vocalizations_dict = {'SealID': [], 'Filepath': [], 'Duration': [], 'VocQuality': [], 'SourceRecPath': [], 'StartTime': [], 'EndTime': [],
                      'RecDate': [], 'RecTime': [], 'RecDuration': [], 'RecHuman': [], 'RecAnimal': [], 'RecPartners': [], 
                      'RecLastKnownLocation': [], 'RecSpecies': []}
missing_days = []
missing_recordings = []

for month in months:
    
    # get folder path for this month in the dataset
    month_folder = get_month_folder(month, month_folders)
    
    # get days from info sheet
    days = np.unique(rec_selection[rec_selection['Month'] == month]['Folder'])
    
    for day in days:
        
        # get folder in dataset; ignore days in info sheet for which we don't have a folder
        day_folder = get_day_folder(day, month_folder, ignore_missing_folders=True)
        if not day_folder:
            missing_days.append(day)
            continue
            
        # get recording names from info sheet
        recs = np.unique(rec_selection[(rec_selection['Month'] == month) & (rec_selection['Folder'] == day)]['Filename'])
        
        for rec in recs:
            
            # ignore lost or deleted recordings
            if 'lost' in rec or 'deleted' in rec:
                continue
                
            # get folder in dataset; ignore recordings in info sheet for which we don't have a folder
            rec_folder = get_rec_folder(rec, day_folder, ignore_missing_folders=True)
            if not rec_folder:
                missing_recordings.append(rec)
                continue
            
            # load the recording sound and textgrid
            rec_wav = get_rec_wav(rec_folder)
            rec_sound = parselmouth.Sound(rec_wav)
            rec_tg = tgt.io.read_textgrid(get_rec_textgrid(rec_folder), encoding='utf-8')
            
            # get all the recording metadata
            rec_info = rec_selection[(rec_selection['Month'] == month) & (rec_selection['Folder'] == day) &
                                                 (rec_selection['Filename'] == rec)]
            assert len(rec_info) == 1, f"Multiple rows in info sheet for recording {rec} on {day}/{month}"
            
            rec_date_str = str(rec_info['Date'].dt.strftime('%Y%m%d').values[0])
            rec_time_int = rec_info['Time'].values[0]
            rec_duration = rec_sound.get_total_duration()
            rec_human = rec_info['Human'].values[0]
            rec_animal = rec_info['Animal'].values[0]
            rec_partners = rec_info['Partners'].values[0]
            rec_location = rec_info['LastKnownLocation'].values[0]
            rec_species = rec_info['Species'].values[0]
            
            seal_tiers = [(t.name, i) for i, t in enumerate(rec_tg.tiers)]
            
            for seal, tier_idx in seal_tiers:
                
                # load all vocalizations for this seal
                seal_folder = check_folder(processed_data_folder + seal + '/')
                u_annotations = rec_tg.tiers[tier_idx].get_annotations_with_text(pattern="u")
                p_annotations = rec_tg.tiers[tier_idx].get_annotations_with_text(pattern="p")
                
                if include_p_vocalizations:
                    annotations = [u_annotations, p_annotations]
                else:
                    annotations = [u_annotations]
                    
                for intervals in annotations:
                    
                    intv_times = [(intv.start_time, intv.end_time) for intv in intervals]
                    intv_texts = [intv.text for intv in intervals]
                    
                    for intv_idx, (start, end) in enumerate(intv_times):
                        voc_sound = rec_sound.extract_part(from_time=start, to_time=end)
                        voc_quality = intv_texts[intv_idx]
                        
                        # save vocalization WAV file
                        voc_filepath = seal_folder + '_'.join([voc_quality, seal, rec_date_str,
                                                rec, f"{intv_idx:03d}"]) + '.WAV'
                        voc_sound.save(voc_filepath, 'WAV')
                        
                        # save metadata to dict
                        vocalizations_dict['SealID'].append(seal)
                        vocalizations_dict['Filepath'].append(voc_filepath)
                        vocalizations_dict['Duration'].append(voc_sound.get_total_duration())
                        vocalizations_dict['VocQuality'].append(voc_quality)
                        vocalizations_dict['SourceRecPath'].append(rec_wav)
                        vocalizations_dict['StartTime'].append(start)
                        vocalizations_dict['EndTime'].append(end)
                        vocalizations_dict['RecDate'].append(rec_date_str)
                        vocalizations_dict['RecTime'].append(rec_time_int)
                        vocalizations_dict['RecDuration'].append(rec_duration)
                        vocalizations_dict['RecHuman'].append(rec_human)
                        vocalizations_dict['RecAnimal'].append(rec_animal)
                        vocalizations_dict['RecPartners'].append(rec_partners)
                        vocalizations_dict['RecLastKnownLocation'].append(rec_location)
                        vocalizations_dict['RecSpecies'].append(rec_species)
# Out:
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 36516 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 19 out of 48688 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 31 out of 24928 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 22831 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 31248 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 16 out of 20234 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 176 out of 37132 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 45 out of 25609 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 29917 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 168 out of 40982 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 25 out of 39062 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 22804 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 35704 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 31107 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 16544 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 40274 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 44418 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 25 out of 39013 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 56 out of 33379 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 52 out of 36803 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 15 out of 16696 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 19389 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 19 out of 32855 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 58154 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 22 out of 20081 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 88 out of 22722 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 42440 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 206 out of 36591 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 33450 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 24990 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 35 out of 25558 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 23 out of 66450 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 104 out of 44744 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 26655 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 29 out of 41422 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 65 out of 31299 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 6 out of 27372 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 12 out of 28122 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 194 out of 32808 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 26 out of 34346 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 6 out of 23068 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 69 out of 31219 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 58 out of 29622 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 6 out of 46373 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 48462 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 12 out of 48265 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 8 out of 28242 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 205 out of 32044 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 194 out of 37475 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 26 out of 40044 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 308 out of 37433 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 26100 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 22 out of 17022 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 21 out of 20010 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 217 out of 38805 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 96 out of 24047 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 12 out of 15243 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 15 out of 44800 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 26106 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 36248 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 124 out of 27099 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 6 out of 15335 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 247 out of 25618 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 183 out of 21910 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 231 out of 27900 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 77 out of 36484 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 64 out of 20245 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 14545 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 131 out of 25945 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 70 out of 18631 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 78 out of 35449 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 50 out of 32177 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 275 out of 27268 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 98 out of 25632 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 341 out of 28493 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 119 out of 15785 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 88 out of 17790 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 18 out of 10041 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 10 out of 13112 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 57 out of 19930 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 70 out of 10692 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 9821 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 101 out of 37631 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 152 out of 21815 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 43 out of 25087 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 25581 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 9 out of 20683 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 40 out of 24949 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 23720 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 21 out of 20984 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 33756 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 18 out of 26457 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 9 out of 63864 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 15 out of 31932 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 16 out of 32844 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 56779 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 49246 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 36367 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 8 out of 67063 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 18048 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 19 out of 26489 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 29846 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 29922 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 45384 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 53 out of 33551 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 13 out of 57027 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 64 out of 36333 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 41412 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 9 out of 34966 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 51 out of 33539 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 40714 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 45871 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 23 out of 34300 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 28515 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 26035 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 13 out of 28928 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 38006 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 48066 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 8 out of 32532 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 55 out of 59256 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 23237 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 53556 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 41 out of 47180 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 30209 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 32 out of 43764 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 319 out of 37955 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 221 out of 47637 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 12 out of 37315 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 31 out of 40080 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 38 out of 31326 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 28101 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 56583 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 72 out of 46989 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 55475 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 114 out of 47432 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 30405 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 16429 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 39 out of 27803 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 14 out of 30576 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 38103 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 119 out of 36388 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 80 out of 23603 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 156 out of 29504 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 99 out of 42289 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 151 out of 31471 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 640 out of 42289 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 16 out of 56058 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 44 out of 51140 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 204 out of 41305 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 26554 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 8 out of 37372 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 38 out of 38355 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 21 out of 41306 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 118 out of 31471 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 137 out of 39339 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 13 out of 36388 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 160 out of 46223 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 115 out of 42290 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 18 out of 39339 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 15 out of 40215 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 260 out of 65031 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 46 out of 37949 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 72 out of 61760 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 14 out of 52831 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 9 out of 48366 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 37 out of 48366 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 170 out of 73665 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 9 out of 33096 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 30893 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 10 out of 46726 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 40649 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 53860 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 185 out of 74183 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 20 out of 38616 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 79 out of 49178 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 35 out of 32228 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 31480 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 55021 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 11 out of 42080 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 323 out of 59931 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 90 out of 54831 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 42074 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 27 out of 45786 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 28 out of 56923 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 126 out of 55686 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 30 out of 34649 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 10 out of 37926 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 14 out of 35364 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 9 out of 41258 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 31412 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 142 out of 53173 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 52335 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 16 out of 34109 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 32651 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 35760 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 28962 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 36470 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 8 out of 39632 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 32356 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 32411 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 44285 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 31 out of 32163 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 23587 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 101 out of 32519 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 51421 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 114 out of 45608 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 32 out of 68430 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 34964 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 38160 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 56050 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 42852 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 61040 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 72531 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 38061 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 34 out of 65618 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 43385 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 11 out of 53555 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 75 out of 39576 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 140 out of 70445 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 13 out of 72682 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 40252 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 60 out of 58174 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 363 out of 49417 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 34788 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 29927 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 62 out of 41713 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 33759 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 38 out of 47220 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 21 out of 46475 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 45358 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 45 out of 34113 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 54 out of 34201 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 31 out of 47969 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 53757 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 132 out of 52662 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 110 out of 45707 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 25 out of 46204 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 37085 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 17661 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 76668 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 40 out of 37238 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 24 out of 43810 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 272 out of 56406 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 60 out of 40072 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 106 out of 35278 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 28 out of 66931 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 28 out of 29276 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 58534 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 10 out of 36340 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 47 out of 29714 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 8 out of 29578 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 58245 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 69 out of 28256 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 90 out of 34091 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 16 out of 36476 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 42347 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 50089 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 37 out of 50688 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 56821 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 37401 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 60995 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 46203 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 8 out of 76459 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 46013 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 34723 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 35974 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 15 out of 47590 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 30 out of 35175 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 26329 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 6 out of 44720 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 36 out of 38921 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 38133 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 6 out of 54665 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 11 out of 58404 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 59 out of 66777 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 66 out of 68271 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 50 out of 57898 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 51 out of 51181 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 12 out of 36716 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 68 out of 47023 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 34 out of 39573 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# ...
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 16 out of 41652 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 14 out of 74094 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 46002 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 45357 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 77503 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 45460 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 82553 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 12 out of 32826 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 31164 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 38779 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 13 out of 44121 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 39962 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 41159 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 26026 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 67 out of 36437 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 39 out of 43724 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 129 out of 39400 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 84 out of 48575 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 14 out of 39400 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 113 out of 39280 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 12 out of 52877 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 51 out of 38776 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 14 out of 30541 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 38020 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 14 out of 38643 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 14 out of 37315 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 11 out of 33657 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 27 out of 45310 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 40 out of 58823 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 31 out of 41335 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 34806 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 44086 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 29 out of 44860 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 23 out of 48372 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 36624 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 45 out of 33170 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 29362 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 6 out of 33749 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 24898 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 38238 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 8 out of 42356 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 32943 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 65 out of 31618 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 9 out of 43778 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 58573 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 11 out of 31478 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 39 out of 39199 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 40334 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 37166 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 49 out of 36452 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 33593 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 9 out of 35269 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 34651 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 42 out of 45012 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 10 out of 41431 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 37851 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 34 out of 38268 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 8 out of 41371 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 41 out of 35682 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 158 out of 45471 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 10 out of 60234 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 12 out of 34251 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 40156 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 5 out of 49014 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 33630 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 73 out of 39070 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 3 out of 36597 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 38155 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 60 out of 30640 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 30061 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 41 out of 32375 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 21 out of 19907 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 8 out of 24219 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 26 out of 22928 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 131 out of 41981 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 49 out of 36581 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 126 out of 42934 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 46170 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 2 out of 42568 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 37733 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 15 out of 24066 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 20 out of 25289 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 1 out of 17985 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 7 out of 24092 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 6 out of 40613 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 18 out of 53516 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 18 out of 43658 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 9 out of 60556 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 52 out of 60976 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 10 out of 35894 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# CPU times: user 38.4 s, sys: 21.2 s, total: 59.6 s
# Wall time: 59.5 s
# <timed exec>:88: PraatWarning: Writing samples to audio file: 4 out of 23493 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 21 out of 29858 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.
# <timed exec>:88: PraatWarning: Writing samples to audio file: 70 out of 30107 samples have been clipped.
# Advice: you could scale the amplitudes or write to a binary file.

# %%
vocalizations_df = pd.DataFrame.from_dict(vocalizations_dict)
print(f'Saved {len(vocalizations_df)} vocalizations.')
print(f'(Skipped {len(missing_days)} days and {len(missing_recordings)} recordings from the info sheet)')
# Out:
# Saved 24756 vocalizations.
# (Skipped 10 days and 370 recordings from the info sheet)

# %%
vocalizations_df
# Out:
#         SealID                                           Filepath  Duration  \
# 0      r17-207  ../data/vocalizations/r17-207/u_r17-207_201706...  0.892997
# 1      r17-207  ../data/vocalizations/r17-207/u_r17-207_201706...  0.485665
# 2      r17-207  ../data/vocalizations/r17-207/p_r17-207_201706...  0.541039
# 3      r17-207  ../data/vocalizations/r17-207/p_r17-207_201706...  0.459883
# 4      r17-207  ../data/vocalizations/r17-207/p_r17-207_201706...  0.811677
# ...        ...                                                ...       ...
# 24751  r17-289  ../data/vocalizations/r17-289/p_r17-289_201707...  0.523914
# 24752  r17-289  ../data/vocalizations/r17-289/p_r17-289_201707...  0.567574
# 24753  r17-289  ../data/vocalizations/r17-289/p_r17-289_201707...  0.622148
# 24754  r17-289  ../data/vocalizations/r17-289/p_r17-289_201707...  0.729156
# 24755  r17-289  ../data/vocalizations/r17-289/p_r17-289_201707...  0.627229
#
#       VocQuality                                      SourceRecPath  \
# 0              u  ../data/Jarinos/06_june/11/ZOOM0002a/ZOOM0002_...
# 1              u  ../data/Jarinos/06_june/11/ZOOM0002a/ZOOM0002_...
# 2              p  ../data/Jarinos/06_june/11/ZOOM0002a/ZOOM0002_...
# 3              p  ../data/Jarinos/06_june/11/ZOOM0002a/ZOOM0002_...
# 4              p  ../data/Jarinos/06_june/11/ZOOM0002a/ZOOM0002_...
# ...          ...                                                ...
# 24751          p  ../data/Jarinos/07_july/28/ZOOM0024/ZOOM0024_T...
# 24752          p  ../data/Jarinos/07_july/28/ZOOM0024/ZOOM0024_T...
# 24753          p  ../data/Jarinos/07_july/28/ZOOM0024/ZOOM0024_T...
# 24754          p  ../data/Jarinos/07_july/28/ZOOM0024/ZOOM0024_T...
# 24755          p  ../data/Jarinos/07_july/28/ZOOM0024/ZOOM0024_T...
#
#         StartTime     EndTime   RecDate  RecTime  RecDuration RecHuman  \
# 0      218.598254  219.491251  20170611       21   909.989333   Andrea
# 1      224.817901  225.303566  20170611       21   909.989333   Andrea
# 2      155.432636  155.973676  20170611       21   909.989333   Andrea
# 3      157.044934  157.504817  20170611       21   909.989333   Andrea
# 4      192.323886  193.135563  20170611       21   909.989333   Andrea
# ...           ...         ...       ...      ...          ...      ...
# 24751  536.225646  536.749560  20170728       11   648.888000    Marga
# 24752  544.564613  545.132187  20170728       11   648.888000    Marga
# 24753  546.823993  547.446141  20170728       11   648.888000    Marga
# 24754  580.645500  581.374657  20170728       11   648.888000    Marga
# 24755  620.311280  620.938509  20170728       11   648.888000    Marga
#
#       RecAnimal RecPartners RecLastKnownLocation RecSpecies
# 0       r17-207     r17-208                   Q7         PV
# 1       r17-207     r17-208                   Q7         PV
# 2       r17-207     r17-208                   Q7         PV
# 3       r17-207     r17-208                   Q7         PV
# 4       r17-207     r17-208                   Q7         PV
# ...         ...         ...                  ...        ...
# 24751   r17-288     r17-289                   J8         PV
# 24752   r17-288     r17-289                   J8         PV
# 24753   r17-288     r17-289                   J8         PV
# 24754   r17-288     r17-289                   J8         PV
# 24755   r17-288     r17-289                   J8         PV
#
# [24756 rows x 15 columns]

# %%
vocalizations_df.to_csv(processed_data_folder + 'vocalizations_info.csv')
